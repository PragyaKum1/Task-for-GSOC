# %%
pip install codecarbon
# Out:
# Requirement already satisfied: codecarbon in /usr/local/lib/python3.11/dist-packages (2.8.3)
# Requirement already satisfied: arrow in /usr/local/lib/python3.11/dist-packages (from codecarbon) (1.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from codecarbon) (8.1.8)
# Requirement already satisfied: fief-client[cli] in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.20.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from codecarbon) (2.2.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.21.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from codecarbon) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.11/dist-packages (from codecarbon) (12.0.0)
# Requirement already satisfied: questionary in /usr/local/lib/python3.11/dist-packages (from codecarbon) (2.1.0)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.11/dist-packages (from codecarbon) (3.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from codecarbon) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from codecarbon) (13.9.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.15.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from arrow->codecarbon) (2.8.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.11/dist-packages (from arrow->codecarbon) (2.9.0.20241206)
# Requirement already satisfied: httpx<0.28.0,>=0.21.3 in /usr/local/lib/python3.11/dist-packages (from fief-client[cli]->codecarbon) (0.27.2)
# Requirement already satisfied: jwcrypto<2.0.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from fief-client[cli]->codecarbon) (1.5.6)
# Requirement already satisfied: yaspin in /usr/local/lib/python3.11/dist-packages (from fief-client[cli]->codecarbon) (3.1.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->codecarbon) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from pynvml->codecarbon) (12.570.86)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from questionary->codecarbon) (3.0.50)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->codecarbon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->codecarbon) (2.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from typer->codecarbon) (4.13.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.14.0)
# Requirement already satisfied: cryptography>=3.4 in /usr/local/lib/python3.11/dist-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (43.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.17.0)
# Requirement already satisfied: termcolor<2.4.0,>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from yaspin->fief-client[cli]->codecarbon) (2.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.22)
# [codecarbon INFO @ 04:01:41] Energy consumed for RAM : 0.000218 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:01:41] Energy consumed for all CPUs : 0.001948 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:01:41] 0.002166 kWh of electricity used since the beginning.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import AdamW
from codecarbon import EmissionsTracker
import time

def create_rnn_model(input_shape, output_shape):
    x = keras.layers.Input(shape=input_shape)

    y = keras.layers.Conv2D(8, (3,3), activation='relu', padding='same')(x)
    y = keras.layers.Conv2D(8, (3,3), activation='relu', padding='same')(y)
    y = y + x
    y = keras.layers.MaxPooling2D(pool_size=(2,2))(y)

    y = keras.layers.Conv2D(16, (3,3), activation='relu', padding='same')(y)
    y0 = y
    y = keras.layers.Conv2D(16, (3,3), activation='relu', padding='same')(y)
    y = keras.layers.Conv2D(16, (3,3), activation='relu', padding='same')(y)
    y = y0 + y
    y = keras.layers.MaxPooling2D(pool_size=(2,2))(y)

    y = keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(y)
    y1 = y
    y = keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(y)
    y = keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(y)
    y = y1 + y
    y = keras.layers.MaxPooling2D(pool_size=(2,2))(y)

    y = keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')(y)
    y2 = y
    y = keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')(y)
    y = keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')(y)
    y = y2 + y
    y = keras.layers.MaxPooling2D(pool_size=(2,2))(y)

    y = keras.layers.Conv2D(128, (3,3), activation='relu', padding='same')(y)
    y3 = y
    y = keras.layers.Conv2D(128, (3,3), activation='relu', padding='same')(y)
    y = keras.layers.Conv2D(128, (3,3), activation='relu', padding='same')(y)
    y = y3 + y
    y = keras.layers.MaxPooling2D(pool_size=(2,2))(y)

    y = keras.layers.Conv2D(256, (3,3), activation='relu', padding='same')(y)

    y = keras.layers.GlobalAveragePooling2D()(y)
    y = keras.layers.Dropout(0.5)(y)
    y = keras.layers.Dense(output_shape, activation='softmax')(y)

    model = keras.models.Model(inputs=x, outputs=y)


    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model


input_shape = (64,64,8)
output_shape = 10

# for the 10 runs
num_runs = 10

for i in range(num_runs):
    tracker = EmissionsTracker(allow_multiple_runs=True)
    tracker.start()

    model = create_rnn_model(input_shape, output_shape)


    emissions = tracker.stop()
# Out:
# [codecarbon WARNING @ 04:02:53] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 04:02:53] [setup] RAM Tracking...
# [codecarbon INFO @ 04:02:53] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:02:53] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 04:02:54] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 04:02:54] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:02:54] [setup] GPU Tracking...
# [codecarbon INFO @ 04:02:54] No GPU found.
# [codecarbon INFO @ 04:02:54] >>> Tracker's metadata:
# [codecarbon INFO @ 04:02:54]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 04:02:54]   Python version: 3.11.11
# [codecarbon INFO @ 04:02:54]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 04:02:54]   Available RAM : 12.675 GB
# [codecarbon INFO @ 04:02:54]   CPU count: 2
# [codecarbon INFO @ 04:02:54]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:02:54]   GPU count: None
# [codecarbon INFO @ 04:02:54]   GPU model: None
# [codecarbon INFO @ 04:02:54] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 04:02:54] Energy consumed for RAM : 0.000000 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:02:54] Energy consumed for all CPUs : 0.000002 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:02:54] 0.000002 kWh of electricity used since the beginning.
# /usr/local/lib/python3.11/dist-packages/codecarbon/output_methods/file.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame.from_records([dict(total.values)])])
# [codecarbon WARNING @ 04:02:54] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 04:02:54] [setup] RAM Tracking...
# [codecarbon INFO @ 04:02:54] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:02:54] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 04:02:56] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 04:02:56] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:02:56] [setup] GPU Tracking...
# [codecarbon INFO @ 04:02:56] No GPU found.
# [codecarbon INFO @ 04:02:56] >>> Tracker's metadata:
# [codecarbon INFO @ 04:02:56]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 04:02:56]   Python version: 3.11.11
# [codecarbon INFO @ 04:02:56]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 04:02:56]   Available RAM : 12.675 GB
# [codecarbon INFO @ 04:02:56]   CPU count: 2
# [codecarbon INFO @ 04:02:56]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:02:56]   GPU count: None
# [codecarbon INFO @ 04:02:56]   GPU model: None
# [codecarbon INFO @ 04:02:56] Energy consumed for RAM : 0.000317 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:02:56] Energy consumed for all CPUs : 0.002833 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:02:56] 0.003150 kWh of electricity used since the beginning.
# [codecarbon INFO @ 04:02:56] 0.003512 g.CO2eq/s mean an estimation of 110.75110677110051 kg.CO2eq/year
# [codecarbon INFO @ 04:02:56] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 04:02:56] Energy consumed for RAM : 0.000000 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:02:56] Energy consumed for all CPUs : 0.000002 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:02:56] 0.000002 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 04:02:56] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 04:02:56] [setup] RAM Tracking...
# [codecarbon INFO @ 04:02:56] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:02:56] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 04:02:57] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 04:02:57] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:02:57] [setup] GPU Tracking...
# [codecarbon INFO @ 04:02:57] No GPU found.
# [codecarbon INFO @ 04:02:57] >>> Tracker's metadata:
# [codecarbon INFO @ 04:02:57]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 04:02:57]   Python version: 3.11.11
# [codecarbon INFO @ 04:02:57]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 04:02:57]   Available RAM : 12.675 GB
# [codecarbon INFO @ 04:02:57]   CPU count: 2
# [codecarbon INFO @ 04:02:57]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:02:57]   GPU count: None
# [codecarbon INFO @ 04:02:57]   GPU model: None
# [codecarbon INFO @ 04:02:57] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 04:02:57] Energy consumed for RAM : 0.000000 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:02:57] Energy consumed for all CPUs : 0.000002 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:02:57] 0.000002 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 04:02:57] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 04:02:57] [setup] RAM Tracking...
# [codecarbon INFO @ 04:02:57] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:02:57] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 04:02:59] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 04:02:59] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:02:59] [setup] GPU Tracking...
# [codecarbon INFO @ 04:02:59] No GPU found.
# [codecarbon INFO @ 04:02:59] >>> Tracker's metadata:
# [codecarbon INFO @ 04:02:59]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 04:02:59]   Python version: 3.11.11
# [codecarbon INFO @ 04:02:59]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 04:02:59]   Available RAM : 12.675 GB
# [codecarbon INFO @ 04:02:59]   CPU count: 2
# [codecarbon INFO @ 04:02:59]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:02:59]   GPU count: None
# [codecarbon INFO @ 04:02:59]   GPU model: None
# [codecarbon INFO @ 04:02:59] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 04:02:59] Energy consumed for RAM : 0.000000 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:02:59] Energy consumed for all CPUs : 0.000003 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:02:59] 0.000003 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 04:02:59] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 04:02:59] [setup] RAM Tracking...
# [codecarbon INFO @ 04:02:59] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:02:59] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 04:03:01] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 04:03:01] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:01] [setup] GPU Tracking...
# [codecarbon INFO @ 04:03:01] No GPU found.
# [codecarbon INFO @ 04:03:01] >>> Tracker's metadata:
# [codecarbon INFO @ 04:03:01]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 04:03:01]   Python version: 3.11.11
# [codecarbon INFO @ 04:03:01]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 04:03:01]   Available RAM : 12.675 GB
# [codecarbon INFO @ 04:03:01]   CPU count: 2
# [codecarbon INFO @ 04:03:01]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:01]   GPU count: None
# [codecarbon INFO @ 04:03:01]   GPU model: None
# [codecarbon INFO @ 04:03:01] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 04:03:01] Energy consumed for RAM : 0.000000 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:03:01] Energy consumed for all CPUs : 0.000003 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:03:01] 0.000003 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 04:03:01] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 04:03:01] [setup] RAM Tracking...
# [codecarbon INFO @ 04:03:01] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:03:01] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 04:03:02] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 04:03:02] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:02] [setup] GPU Tracking...
# [codecarbon INFO @ 04:03:02] No GPU found.
# [codecarbon INFO @ 04:03:02] >>> Tracker's metadata:
# [codecarbon INFO @ 04:03:02]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 04:03:02]   Python version: 3.11.11
# [codecarbon INFO @ 04:03:02]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 04:03:02]   Available RAM : 12.675 GB
# [codecarbon INFO @ 04:03:02]   CPU count: 2
# [codecarbon INFO @ 04:03:02]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:02]   GPU count: None
# [codecarbon INFO @ 04:03:02]   GPU model: None
# [codecarbon INFO @ 04:03:02] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 04:03:02] Energy consumed for RAM : 0.000000 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:03:02] Energy consumed for all CPUs : 0.000002 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:03:02] 0.000002 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 04:03:02] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 04:03:02] [setup] RAM Tracking...
# [codecarbon INFO @ 04:03:02] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:03:02] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 04:03:04] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 04:03:04] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:04] [setup] GPU Tracking...
# [codecarbon INFO @ 04:03:04] No GPU found.
# [codecarbon INFO @ 04:03:04] >>> Tracker's metadata:
# [codecarbon INFO @ 04:03:04]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 04:03:04]   Python version: 3.11.11
# [codecarbon INFO @ 04:03:04]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 04:03:04]   Available RAM : 12.675 GB
# [codecarbon INFO @ 04:03:04]   CPU count: 2
# [codecarbon INFO @ 04:03:04]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:04]   GPU count: None
# [codecarbon INFO @ 04:03:04]   GPU model: None
# [codecarbon INFO @ 04:03:04] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 04:03:04] Energy consumed for RAM : 0.000000 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:03:04] Energy consumed for all CPUs : 0.000002 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:03:04] 0.000002 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 04:03:04] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 04:03:04] [setup] RAM Tracking...
# [codecarbon INFO @ 04:03:04] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:03:04] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 04:03:05] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 04:03:05] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:05] [setup] GPU Tracking...
# [codecarbon INFO @ 04:03:05] No GPU found.
# [codecarbon INFO @ 04:03:05] >>> Tracker's metadata:
# [codecarbon INFO @ 04:03:05]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 04:03:05]   Python version: 3.11.11
# [codecarbon INFO @ 04:03:05]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 04:03:05]   Available RAM : 12.675 GB
# [codecarbon INFO @ 04:03:05]   CPU count: 2
# [codecarbon INFO @ 04:03:05]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:05]   GPU count: None
# [codecarbon INFO @ 04:03:05]   GPU model: None
# [codecarbon INFO @ 04:03:05] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 04:03:06] Energy consumed for RAM : 0.000000 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:03:06] Energy consumed for all CPUs : 0.000002 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:03:06] 0.000003 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 04:03:06] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 04:03:06] [setup] RAM Tracking...
# [codecarbon INFO @ 04:03:06] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:03:06] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 04:03:07] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 04:03:07] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:07] [setup] GPU Tracking...
# [codecarbon INFO @ 04:03:07] No GPU found.
# [codecarbon INFO @ 04:03:07] >>> Tracker's metadata:
# [codecarbon INFO @ 04:03:07]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 04:03:07]   Python version: 3.11.11
# [codecarbon INFO @ 04:03:07]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 04:03:07]   Available RAM : 12.675 GB
# [codecarbon INFO @ 04:03:07]   CPU count: 2
# [codecarbon INFO @ 04:03:07]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:07]   GPU count: None
# [codecarbon INFO @ 04:03:07]   GPU model: None
# [codecarbon INFO @ 04:03:07] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 04:03:07] Energy consumed for RAM : 0.000000 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:03:07] Energy consumed for all CPUs : 0.000002 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:03:07] 0.000003 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 04:03:07] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 04:03:07] [setup] RAM Tracking...
# [codecarbon INFO @ 04:03:07] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:03:07] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 04:03:08] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 04:03:08] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:08] [setup] GPU Tracking...
# [codecarbon INFO @ 04:03:08] No GPU found.
# [codecarbon INFO @ 04:03:08] >>> Tracker's metadata:
# [codecarbon INFO @ 04:03:08]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 04:03:08]   Python version: 3.11.11
# [codecarbon INFO @ 04:03:08]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 04:03:08]   Available RAM : 12.675 GB
# [codecarbon INFO @ 04:03:08]   CPU count: 2
# [codecarbon INFO @ 04:03:08]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 04:03:08]   GPU count: None
# [codecarbon INFO @ 04:03:08]   GPU model: None
# [codecarbon INFO @ 04:03:09] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 04:03:09] Energy consumed for RAM : 0.000000 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 04:03:09] Energy consumed for all CPUs : 0.000002 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 04:03:09] 0.000002 kWh of electricity used since the beginning.

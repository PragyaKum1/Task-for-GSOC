# %%
pip install codecarbon
# Out:
# Collecting codecarbon
#   Downloading codecarbon-2.8.3-py3-none-any.whl.metadata (8.7 kB)
# Collecting arrow (from codecarbon)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from codecarbon) (8.1.8)
# Collecting fief-client[cli] (from codecarbon)
#   Downloading fief_client-0.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from codecarbon) (2.2.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.21.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from codecarbon) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.11/dist-packages (from codecarbon) (12.0.0)
# Collecting questionary (from codecarbon)
#   Downloading questionary-2.1.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting rapidfuzz (from codecarbon)
#   Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from codecarbon) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from codecarbon) (13.9.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.15.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from arrow->codecarbon) (2.8.2)
# Collecting types-python-dateutil>=2.8.10 (from arrow->codecarbon)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Collecting httpx<0.28.0,>=0.21.3 (from fief-client[cli]->codecarbon)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jwcrypto<2.0.0,>=1.4 (from fief-client[cli]->codecarbon)
#   Downloading jwcrypto-1.5.6-py3-none-any.whl.metadata (3.1 kB)
# Collecting yaspin (from fief-client[cli]->codecarbon)
#   Downloading yaspin-3.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->codecarbon) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from pynvml->codecarbon) (12.570.86)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from questionary->codecarbon) (3.0.50)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->codecarbon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->codecarbon) (2.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from typer->codecarbon) (4.13.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.14.0)
# Requirement already satisfied: cryptography>=3.4 in /usr/local/lib/python3.11/dist-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (43.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.17.0)
# Collecting termcolor<2.4.0,>=2.2.0 (from yaspin->fief-client[cli]->codecarbon)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.22)
# Downloading codecarbon-2.8.3-py3-none-any.whl (516 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.7/516.7 kB 13.6 MB/s eta 0:00:00
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.2 MB/s eta 0:00:00
# Downloading questionary-2.1.0-py3-none-any.whl (36 kB)
# Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 65.6 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.6 MB/s eta 0:00:00
# Downloading jwcrypto-1.5.6-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 8.0 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Downloading fief_client-0.20.0-py3-none-any.whl (20 kB)
# Downloading yaspin-3.1.0-py3-none-any.whl (18 kB)
# Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Installing collected packages: types-python-dateutil, termcolor, rapidfuzz, yaspin, questionary, httpx, arrow, jwcrypto, fief-client, codecarbon
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.5.0
#     Uninstalling termcolor-2.5.0:
#       Successfully uninstalled termcolor-2.5.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.8.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# Successfully installed arrow-1.3.0 codecarbon-2.8.3 fief-client-0.20.0 httpx-0.27.2 jwcrypto-1.5.6 questionary-2.1.0 rapidfuzz-3.12.2 termcolor-2.3.0 types-python-dateutil-2.9.0.20241206 yaspin-3.1.0

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import AdamW
from codecarbon import EmissionsTracker
import time

def create_rnn_model(input_shape, output_shape):
    x = keras.layers.Input(shape=input_shape)

    y = keras.layers.Conv2D(8, (3,3), activation='relu', padding='same')(x)
    y = keras.layers.Conv2D(8, (3,3), activation='relu', padding='same')(y)
    y = y + x
    y = keras.layers.MaxPooling2D(pool_size=(2,2))(y)

    y = keras.layers.Conv2D(16, (3,3), activation='relu', padding='same')(y)
    y0 = y
    y = keras.layers.Conv2D(16, (3,3), activation='relu', padding='same')(y)
    y = keras.layers.Conv2D(16, (3,3), activation='relu', padding='same')(y)
    y = y0 + y
    y = keras.layers.MaxPooling2D(pool_size=(2,2))(y)

    y = keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(y)
    y1 = y
    y = keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(y)
    y = keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(y)
    y = y1 + y
    y = keras.layers.MaxPooling2D(pool_size=(2,2))(y)

    y = keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')(y)
    y2 = y
    y = keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')(y)
    y = keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')(y)
    y = y2 + y
    y = keras.layers.MaxPooling2D(pool_size=(2,2))(y)

    y = keras.layers.Conv2D(128, (3,3), activation='relu', padding='same')(y)
    y3 = y
    y = keras.layers.Conv2D(128, (3,3), activation='relu', padding='same')(y)
    y = keras.layers.Conv2D(128, (3,3), activation='relu', padding='same')(y)
    y = y3 + y
    y = keras.layers.MaxPooling2D(pool_size=(2,2))(y)

    y = keras.layers.Conv2D(256, (3,3), activation='relu', padding='same')(y)

    y = keras.layers.GlobalAveragePooling2D()(y)
    y = keras.layers.Dropout(0.5)(y)
    y = keras.layers.Dense(output_shape, activation='softmax')(y)

    model = keras.models.Model(inputs=x, outputs=y)


    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model


input_shape = (64,64,8)
output_shape = 10

# for the 10 runs
num_runs = 10
emission_results = []

for i in range(num_runs):
    tracker = EmissionsTracker(allow_multiple_runs=True)
    tracker.start()

    start_time = time.time()

    model = create_rnn_model(input_shape, output_shape)


    emissions = tracker.stop()
# Out:
# [codecarbon WARNING @ 20:17:55] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:17:55] [setup] RAM Tracking...
# [codecarbon INFO @ 20:17:55] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:17:55] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 20:17:57] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 20:17:57] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:17:57] [setup] GPU Tracking...
# [codecarbon INFO @ 20:17:57] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:17:57] >>> Tracker's metadata:
# [codecarbon INFO @ 20:17:57]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 20:17:57]   Python version: 3.11.11
# [codecarbon INFO @ 20:17:57]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 20:17:57]   Available RAM : 12.675 GB
# [codecarbon INFO @ 20:17:57]   CPU count: 2
# [codecarbon INFO @ 20:17:57]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:17:57]   GPU count: 1
# [codecarbon INFO @ 20:17:57]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 20:17:57] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 20:17:59] Energy consumed for RAM : 0.000003 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:17:59] Energy consumed for all CPUs : 0.000025 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:17:59] Energy consumed for all GPUs : 0.000017 kWh. Total GPU Power : 28.69465607360497 W
# [codecarbon INFO @ 20:17:59] 0.000044 kWh of electricity used since the beginning.
# /usr/local/lib/python3.11/dist-packages/codecarbon/output_methods/file.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame.from_records([dict(total.values)])])
# [codecarbon WARNING @ 20:17:59] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:17:59] [setup] RAM Tracking...
# [codecarbon INFO @ 20:17:59] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:17:59] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon INFO @ 20:18:00] Energy consumed for RAM : 0.000020 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:00] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:00] Energy consumed for all GPUs : 0.000120 kWh. Total GPU Power : 28.710329144516113 W
# [codecarbon INFO @ 20:18:00] 0.000317 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 20:18:00] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 20:18:00] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:00] [setup] GPU Tracking...
# [codecarbon INFO @ 20:18:00] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:18:00] >>> Tracker's metadata:
# [codecarbon INFO @ 20:18:00]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 20:18:00]   Python version: 3.11.11
# [codecarbon INFO @ 20:18:00]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 20:18:00]   Available RAM : 12.675 GB
# [codecarbon INFO @ 20:18:00]   CPU count: 2
# [codecarbon INFO @ 20:18:00]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:00]   GPU count: 1
# [codecarbon INFO @ 20:18:00]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 20:18:00] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 20:18:02] Energy consumed for RAM : 0.000003 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:02] Energy consumed for all CPUs : 0.000025 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:02] Energy consumed for all GPUs : 0.000017 kWh. Total GPU Power : 28.673923843092773 W
# [codecarbon INFO @ 20:18:02] 0.000044 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 20:18:02] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:18:02] [setup] RAM Tracking...
# [codecarbon INFO @ 20:18:02] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:18:02] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 20:18:04] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 20:18:04] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:04] [setup] GPU Tracking...
# [codecarbon INFO @ 20:18:04] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:18:04] >>> Tracker's metadata:
# [codecarbon INFO @ 20:18:04]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 20:18:04]   Python version: 3.11.11
# [codecarbon INFO @ 20:18:04]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 20:18:04]   Available RAM : 12.675 GB
# [codecarbon INFO @ 20:18:04]   CPU count: 2
# [codecarbon INFO @ 20:18:04]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:04]   GPU count: 1
# [codecarbon INFO @ 20:18:04]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 20:18:04] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 20:18:06] Energy consumed for RAM : 0.000003 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:06] Energy consumed for all CPUs : 0.000025 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:06] Energy consumed for all GPUs : 0.000017 kWh. Total GPU Power : 28.734188980155878 W
# [codecarbon INFO @ 20:18:06] 0.000044 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 20:18:06] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:18:06] [setup] RAM Tracking...
# [codecarbon INFO @ 20:18:06] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:18:06] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 20:18:07] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 20:18:07] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:07] [setup] GPU Tracking...
# [codecarbon INFO @ 20:18:07] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:18:07] >>> Tracker's metadata:
# [codecarbon INFO @ 20:18:07]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 20:18:07]   Python version: 3.11.11
# [codecarbon INFO @ 20:18:07]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 20:18:07]   Available RAM : 12.675 GB
# [codecarbon INFO @ 20:18:07]   CPU count: 2
# [codecarbon INFO @ 20:18:07]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:07]   GPU count: 1
# [codecarbon INFO @ 20:18:07]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 20:18:08] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 20:18:10] Energy consumed for RAM : 0.000003 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:10] Energy consumed for all CPUs : 0.000025 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:10] Energy consumed for all GPUs : 0.000017 kWh. Total GPU Power : 28.633332056537753 W
# [codecarbon INFO @ 20:18:10] 0.000045 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 20:18:10] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:18:10] [setup] RAM Tracking...
# [codecarbon INFO @ 20:18:10] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:18:10] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 20:18:11] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 20:18:11] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:11] [setup] GPU Tracking...
# [codecarbon INFO @ 20:18:11] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:18:11] >>> Tracker's metadata:
# [codecarbon INFO @ 20:18:11]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 20:18:11]   Python version: 3.11.11
# [codecarbon INFO @ 20:18:11]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 20:18:11]   Available RAM : 12.675 GB
# [codecarbon INFO @ 20:18:11]   CPU count: 2
# [codecarbon INFO @ 20:18:11]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:11]   GPU count: 1
# [codecarbon INFO @ 20:18:11]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 20:18:11] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 20:18:13] Energy consumed for RAM : 0.000003 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:13] Energy consumed for all CPUs : 0.000025 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:13] Energy consumed for all GPUs : 0.000017 kWh. Total GPU Power : 28.548908882856793 W
# [codecarbon INFO @ 20:18:13] 0.000045 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 20:18:13] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:18:13] [setup] RAM Tracking...
# [codecarbon INFO @ 20:18:13] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:18:13] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 20:18:14] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 20:18:14] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:14] [setup] GPU Tracking...
# [codecarbon INFO @ 20:18:14] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:18:14] >>> Tracker's metadata:
# [codecarbon INFO @ 20:18:14]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 20:18:14]   Python version: 3.11.11
# [codecarbon INFO @ 20:18:14]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 20:18:14]   Available RAM : 12.675 GB
# [codecarbon INFO @ 20:18:14]   CPU count: 2
# [codecarbon INFO @ 20:18:14]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:14]   GPU count: 1
# [codecarbon INFO @ 20:18:14]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 20:18:15] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 20:18:15] Energy consumed for RAM : 0.000040 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:15] Energy consumed for all CPUs : 0.000354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:15] Energy consumed for all GPUs : 0.000239 kWh. Total GPU Power : 28.579410887696167 W
# [codecarbon INFO @ 20:18:15] 0.000633 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:18:17] Energy consumed for RAM : 0.000003 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:17] Energy consumed for all CPUs : 0.000025 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:17] Energy consumed for all GPUs : 0.000017 kWh. Total GPU Power : 28.707343986882297 W
# [codecarbon INFO @ 20:18:17] 0.000044 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 20:18:17] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:18:17] [setup] RAM Tracking...
# [codecarbon INFO @ 20:18:17] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:18:17] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 20:18:18] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 20:18:18] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:18] [setup] GPU Tracking...
# [codecarbon INFO @ 20:18:18] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:18:18] >>> Tracker's metadata:
# [codecarbon INFO @ 20:18:18]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 20:18:18]   Python version: 3.11.11
# [codecarbon INFO @ 20:18:18]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 20:18:18]   Available RAM : 12.675 GB
# [codecarbon INFO @ 20:18:18]   CPU count: 2
# [codecarbon INFO @ 20:18:18]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:18]   GPU count: 1
# [codecarbon INFO @ 20:18:18]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 20:18:18] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 20:18:20] Energy consumed for RAM : 0.000003 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:20] Energy consumed for all CPUs : 0.000025 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:20] Energy consumed for all GPUs : 0.000017 kWh. Total GPU Power : 28.771537370528822 W
# [codecarbon INFO @ 20:18:20] 0.000044 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 20:18:20] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:18:20] [setup] RAM Tracking...
# [codecarbon INFO @ 20:18:20] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:18:20] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 20:18:22] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 20:18:22] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:22] [setup] GPU Tracking...
# [codecarbon INFO @ 20:18:22] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:18:22] >>> Tracker's metadata:
# [codecarbon INFO @ 20:18:22]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 20:18:22]   Python version: 3.11.11
# [codecarbon INFO @ 20:18:22]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 20:18:22]   Available RAM : 12.675 GB
# [codecarbon INFO @ 20:18:22]   CPU count: 2
# [codecarbon INFO @ 20:18:22]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:22]   GPU count: 1
# [codecarbon INFO @ 20:18:22]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 20:18:22] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 20:18:24] Energy consumed for RAM : 0.000003 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:24] Energy consumed for all CPUs : 0.000025 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:24] Energy consumed for all GPUs : 0.000017 kWh. Total GPU Power : 28.753458454578844 W
# [codecarbon INFO @ 20:18:24] 0.000044 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 20:18:24] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:18:24] [setup] RAM Tracking...
# [codecarbon INFO @ 20:18:24] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:18:24] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 20:18:25] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 20:18:25] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:25] [setup] GPU Tracking...
# [codecarbon INFO @ 20:18:25] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:18:25] >>> Tracker's metadata:
# [codecarbon INFO @ 20:18:25]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 20:18:25]   Python version: 3.11.11
# [codecarbon INFO @ 20:18:25]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 20:18:25]   Available RAM : 12.675 GB
# [codecarbon INFO @ 20:18:25]   CPU count: 2
# [codecarbon INFO @ 20:18:25]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:25]   GPU count: 1
# [codecarbon INFO @ 20:18:25]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 20:18:25] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 20:18:27] Energy consumed for RAM : 0.000003 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:27] Energy consumed for all CPUs : 0.000025 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:27] Energy consumed for all GPUs : 0.000017 kWh. Total GPU Power : 28.789685472109415 W
# [codecarbon INFO @ 20:18:27] 0.000044 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 20:18:28] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 20:18:28] [setup] RAM Tracking...
# [codecarbon INFO @ 20:18:28] [setup] CPU Tracking...
# [codecarbon WARNING @ 20:18:28] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 20:18:29] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 20:18:29] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:29] [setup] GPU Tracking...
# [codecarbon INFO @ 20:18:29] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 20:18:29] >>> Tracker's metadata:
# [codecarbon INFO @ 20:18:29]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 20:18:29]   Python version: 3.11.11
# [codecarbon INFO @ 20:18:29]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 20:18:29]   Available RAM : 12.675 GB
# [codecarbon INFO @ 20:18:29]   CPU count: 2
# [codecarbon INFO @ 20:18:29]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 20:18:29]   GPU count: 1
# [codecarbon INFO @ 20:18:29]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 20:18:29] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 20:18:30] Energy consumed for RAM : 0.000059 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:30] Energy consumed for all CPUs : 0.000531 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:30] Energy consumed for all GPUs : 0.000359 kWh. Total GPU Power : 28.859500002784678 W
# [codecarbon INFO @ 20:18:30] 0.000950 kWh of electricity used since the beginning.
# [codecarbon INFO @ 20:18:31] Energy consumed for RAM : 0.000003 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 20:18:31] Energy consumed for all CPUs : 0.000025 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 20:18:31] Energy consumed for all GPUs : 0.000017 kWh. Total GPU Power : 28.805698538725345 W
# [codecarbon INFO @ 20:18:31] 0.000044 kWh of electricity used since the beginning.
